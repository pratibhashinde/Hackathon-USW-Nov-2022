# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel('therisingcostoflivinganditsimpactonindividualsingreatbritain22042022124930.xlsx',sheet_name='Table_1b')
print(data)
# Out:
#                              Table 1b: Cost of living         Unnamed: 1  \
# 0                  Great Britain, 16 to 27 March 2022                NaN
# 1   Source: Opinions and Lifestyle Survey (COVID-1...                NaN
# 2                       Date published: 25 April 2022                NaN
# 3   Some cells refer to notes which can be found i...                NaN
# 4   Freeze panes are turned on. To turn off freeze...                NaN
# 5                         Return to table of contents                NaN
# 6                                                 NaN  All persons total
# 7                                                 NaN                  %
# 8                                                 NaN                NaN
# 9   Over the last month, has your cost of living c...                NaN
# 10                    My cost of living has increased                 87
# 11              My cost of living has stayed the same                 13
# ...

# %%
data.shape
# Out:
# (51, 44)

# %%
data.columns
# Out:
# Index(['Table 1b: Cost of living', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
#        'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43'],
#       dtype='object')

# %%
df=data[['Table 1b: Cost of living', 'Unnamed: 1']]
print(df)
# Out:
#                              Table 1b: Cost of living         Unnamed: 1
# 0                  Great Britain, 16 to 27 March 2022                NaN
# 1   Source: Opinions and Lifestyle Survey (COVID-1...                NaN
# 2                       Date published: 25 April 2022                NaN
# 3   Some cells refer to notes which can be found i...                NaN
# 4   Freeze panes are turned on. To turn off freeze...                NaN
# 5                         Return to table of contents                NaN
# 6                                                 NaN  All persons total
# 7                                                 NaN                  %
# 8                                                 NaN                NaN
# 9   Over the last month, has your cost of living c...                NaN
# 10                    My cost of living has increased                 87
# 11              My cost of living has stayed the same                 13
# ...

# %%
df1=df.iloc[19:28,:]
print(df1)
# Out:
#                           Table 1b: Cost of living Unnamed: 1
# 19              My income or earnings have reduced          8
# 20           I have lost my job or stopped working          1
# 21                  My hours of work have reduced           3
# 22      My gas or electricity bills have increased         83
# 23        My rent or mortgage costs have increased         17
# 24         The price of my food shop has increased         88
# 25              The price of my fuel has increased         77
# 26  The price of my public transport has increased         15
# 27                                           Other          4

# %%
df1['Reason for Increase in Cost of Living']=df1['Table 1b: Cost of living']
df1['Percentage']=df['Unnamed: 1']
final_df=df1[['Reason for Increase in Cost of Living','Percentage']].reset_index(inplace=False,drop=True)
print(final_df)
# Out:
#             Reason for Increase in Cost of Living Percentage
# 0              My income or earnings have reduced          8
# 1           I have lost my job or stopped working          1
# 2                  My hours of work have reduced           3
# 3      My gas or electricity bills have increased         83
# 4        My rent or mortgage costs have increased         17
# 5         The price of my food shop has increased         88
# 6              The price of my fuel has increased         77
# 7  The price of my public transport has increased         15
# 8                                           Other          4
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
final_df.to_csv('Cost_of_living.csv')
